# %%
import pandas as pd
from xml.etree import ElementTree as ET
from pathlib import Path

def check_xml_well_formed(xml_path):
    """
    Check if an XML file is well-formed.
    Returns True if well-formed, raises ParseError with details if not.
    """
    try:
        tree = ET.parse(xml_path)
        print(f"✓ XML file '{xml_path}' is well-formed")
        return True
    except ET.ParseError as e:
        print(f"✗ XML parsing error in '{xml_path}':")
        print(f"  Line {e.position[0]}, Column {e.position[1]}")
        print(f"  Error: {str(e)}")
        raise

# Check XML well-formedness before attempting to read
xml_file = 'ICTRP-Results.xml'
if Path(xml_file).exists():
    check_xml_well_formed(xml_file)
    # Read the XML file into a DataFrame using etree parser
    df = pd.read_xml(xml_file, parser='etree')

    # Display basic information about the DataFrame
    print("\nDataFrame Info:")
    print(df.info()) 
else:
    print(f"File not found: {xml_file}")
# Out:
# ✓ XML file 'ICTRP-Results.xml' is well-formed
#            Export_date  Internal_Number                 TrialID  \
# 0  03/19/2025 12:20:45         14746198  ChiCTR2500098323\n
# 1  03/19/2025 12:20:45         14745527       NCT06864702\n
# 2  03/19/2025 12:20:45         14745953  ChiCTR2500098075\n
# 3  03/19/2025 12:20:45         14706466   TCTR20250302004\n
# 4  03/19/2025 12:20:45         14705480        KCT0010243\n
#
#      Last_Refreshed_on                                       Public_title  \
# 0  10 March 2025\n      A prospective, multi-center study to character...
# 1  10 March 2025\n      The Construction and Effect Verification of a ...
# 2  10 March 2025\n      Diagnosis and treatment of obstructive sleep a...
# 3   3 March 2025\n      Accuracy of radiographic fracture detection pr...
# 4   3 March 2025\n      Verification of clinical efficacy of artificia...
#
#                                     Scientific_title  \
# 0  A prospective, multi-center study to character...
# 1  The Construction and Effect Verification of a ...
# 2  Diagnosis and treatment of obstructive sleep a...
# 3  Accuracy of radiographic fracture detection pr...
# 4  Verification of clinical efficacy of artificia...
#
#                                      Primary_sponsor Retrospective_flag  \
# 0  First Affiliated Hospital of Sun Yat-sen Unive...          Yes\n
# 1                            Zhujiang Hospital\n               No\n
# 2                 Shanghai Children's Hospital\n              Yes\n
# 3                                          N/A\n               No\n
# 4                     Inha University Hospital\n              Yes\n
#
#    Date_registration3 Date_registration  ...  \
# 0            20250306  2025-03-06\n      ...
# 1            20250304  04/03/2025\n      ...
# 2            20250303  2025-03-03\n      ...
# 3            20250302  02/03/2025\n      ...
# 4            20250228  2025-02-28\n      ...
#
#                        Ethics_review_contact_address  \
# 0                                Zhanyong Chen\n
# 1                                               None
# 2                                       He Lei\n
# 3  Faculty of Medicine Vajira Hospital Ethics Com...
# 4              IRB of Inha University Hospital\n
#
#   Ethics_review_contact_phone Ethics_review_contact_email results_url_link  \
# 0      +86 20 8733 8035\n                            None             None
# 1                        None                        None             None
# 2      +86 21 5297 6581\n      hl@shchildren.com.cn\n                 None
# 3      6622443843 Ext. \n        virb.vjr@nmu.ac.th\n                 None
# 4       +82-32-890-3691\n                            None             None
#
#   Acronym          Secondary_ID results_yes_no results_date_completed  \
# 0    None                  None           None                   None
# 1    None  2024-KY-152-02\n               None                   None
# 2    None                  None           None                   None
# 3    None       Nil Known\n               None       31/01/2025\n
# 4    None                  None           None                   None
#
#   Secondary_Sponsor results_date_posted
# 0              None                None
# 1              None                None
# 2              None                None
# 3              None                None
# 4              None                None
#
# [5 rows x 49 columns]
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2681 entries, 0 to 2680
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Export_date                    2681 non-null   object
#  1   Internal_Number                2681 non-null   int64
#  2   TrialID                        2681 non-null   object
#  3   Last_Refreshed_on              2681 non-null   object
#  4   Public_title                   2681 non-null   object
#  5   Scientific_title               2680 non-null   object
#  6   Primary_sponsor                2680 non-null   object
#  7   Retrospective_flag             2681 non-null   object
#  8   Date_registration3             2681 non-null   int64
#  9   Date_registration              2681 non-null   object
#  10  Source_Register                2681 non-null   object
#  11  web_address                    2681 non-null   object
#  12  Recruitment_Status             2678 non-null   object
#  13  other_records                  2681 non-null   object
#  14  Inclusion_agemin               2304 non-null   object
#  15  Inclusion_agemax               2222 non-null   object
#  16  Inclusion_gender               2508 non-null   object
#  17  Date_enrollement               2679 non-null   object
#  18  Target_size                    2668 non-null   object
#  19  Study_type                     2681 non-null   object
#  20  Study_design                   1881 non-null   object
#  21  Phase                          1840 non-null   object
#  22  Countries                      2526 non-null   object
#  23  Contact_Firstname              2318 non-null   object
#  24  Contact_Lastname               1418 non-null   object
#  25  Contact_Address                1253 non-null   object
#  26  Contact_Email                  2044 non-null   object
#  27  Contact_Tel                    2022 non-null   object
#  28  Contact_Affiliation            1986 non-null   object
#  29  Inclusion_Criteria             2649 non-null   object
#  30  Exclusion_Criteria             1363 non-null   object
#  31  Condition                      2619 non-null   object
#  32  Intervention                   2215 non-null   object
#  33  Primary_outcome                2646 non-null   object
#  34  Secondary_outcome              1700 non-null   object
#  35  Source_Support                 2636 non-null   object
#  36  Ethics_review_status           1288 non-null   object
#  37  Ethics_review_approval_date    1354 non-null   object
#  38  Ethics_review_contact_name     379 non-null    object
#  39  Ethics_review_contact_address  1237 non-null   object
#  40  Ethics_review_contact_phone    763 non-null    object
#  41  Ethics_review_contact_email    372 non-null    object
#  42  results_url_link               79 non-null     object
#  43  Acronym                        520 non-null    object
#  44  Secondary_ID                   1644 non-null   object
#  45  results_yes_no                 263 non-null    object
#  46  results_date_completed         303 non-null    object
#  47  Secondary_Sponsor              571 non-null    object
#  48  results_date_posted            59 non-null     object
# dtypes: int64(2), object(47)
# memory usage: 1.0+ MB
# None

# %%
from collections import Counter
# Get all characters from Countries column and count frequencies
chars = ''.join(df.Countries.fillna(''))


char_counts = Counter(chars)
char_counts
# Out:
# Counter({' ': 10764,
#          'a': 3108,
#          'n': 2661,
#          '\n': 2526,
#          'i': 2296,
#          'e': 1417,
#          'h': 1147,
#          't': 1111,
#          'C': 1097,
#          'd': 926,
#          'r': 699,
#          'l': 573,
#          'o': 546,
#          ';': 446,
#          'p': 414,
#          's': 400,
#          'S': 388,
#          'U': 347,
#          'g': 337,
#          'y': 336,
#          'u': 333,
#          'I': 331,
#          'm': 300,
#          'K': 268,
#          'c': 265,
#          'T': 160,
#          'J': 152,
#          'R': 140,
#          'w': 139,
#          'b': 137,
#          'f': 125,
#          ',': 118,
#          'G': 107,
#          'A': 107,
#          'F': 101,
#          'k': 96,
#          'E': 78,
#          'N': 76,
#          'z': 56,
#          'B': 53,
#          'P': 36,
#          'H': 36,
#          'D': 16,
#          'M': 14,
#          'x': 11,
#          'Z': 11,
#          '(': 10,
#          ')': 10,
#          'L': 8,
#          'v': 8,
#          'V': 5,
#          'W': 4,
#          'q': 2,
#          'j': 1})

# %%
# Find all parenthetical text in the Countries column
[chars[i:j+1] for i, j in zip([i for i, c in enumerate(chars) if c == '('], 
                             [i for i, c in enumerate(chars) if c == ')'])]
# Out:
# ['(Islamic Republic of)',
#  '(Islamic Republic of)',
#  '(Islamic Republic of)',
#  '(Islamic Republic of)',
#  '(Islamic Republic of)',
#  '(except Japan)',
#  '(except Japan)',
#  '(Islamic Republic of)',
#  '(Islamic Republic of)',
#  '(except Japan)']

# %%
import pandas as pd
from pathlib import Path

def find_unused_character(file_path, start=32, end=127):
    """
    Find a character that's not present in the CSV file.
    
    Args:
        file_path: Path to the CSV file
        start: Starting ASCII value (default 32 = space)
        end: Ending ASCII value (default 127 = last printable ASCII)
    
    Returns:
        A character that's not present in the file, or None if all characters are used
    """
    # Read the entire file as text
    text = Path(file_path).read_text(encoding='utf-8')

    returns = {chr(i) for i in range(start, end) if chr(i) not in text}
    
    for i in returns:
        print(f"Found unused character: '{i}' (ASCII: {ord(i)})")
    
    return returns

# Find an unused character in the CSV
csv_file = 'IctrpResults.csv'
if Path(csv_file).exists():
    unused_char = find_unused_character(csv_file)
else:
    print(f"File not found: {csv_file}")
# Out:
# Found unused character: '$' (ASCII: 36)
